# %%
fully_mortgage=int(input('رهن کامل خونه ای که قصد اجاره داری چقدره؟\n'))
expectedـinflation=int(input('نرخ تورمی که انتظار داری در ایران، توی یک سال آینده داشته باشیم؟\n'))
expected_gold_growth=int(input('به نظرت طلا یا دلار در یک سال آینده، چند درصد میتونه رشد داشته باشه؟\n'))
investment=int(input('در بهترین حالت، بیشترین اجاره خانه ای که توان پرداختش را داری چقدره؟\n'))

for i in range((fully_mortgage//50000000)+1):
    mortgage=round(fully_mortgage-(i*50000000))
    monthly_rent=round((fully_mortgage-mortgage)*0.03)
    if monthly_rent<=investment:
        init=investment-monthly_rent
        intrest_rate=0.025
        n=12
        Total=init*(1+intrest_rate)
        for i in range(n-1):
            Total=round((Total+init)*(1+intrest_rate))
        investment_profit=round((fully_mortgage-mortgage)*(expected_gold_growth/100))+Total
        cost=round((monthly_rent*12)+(mortgage-(mortgage/(1+(expectedـinflation/100)))))
        Total=investment_profit-cost
    else:
        break
    print(f'\n\n\n<< Mortgage = {mortgage:,} >>\n<< Rent = {monthly_rent:,} >>')
    print(f'\nprofit:{investment_profit:,}')
    print(f'cost:{cost:,}')
    print(f'Total:{Total:,}')
    print('\n---------------------------------------------------\n')
# Out:
# رهن کامل خونه ای که قصد اجاره داری چقدره؟
#  400000000
# نرخ تورمی که انتظار داری در ایران، توی یک سال آینده داشته باشیم؟
#  50
# به نظرت طلا یا دلار در یک سال آینده، چند درصد میتونه رشد داشته باشه؟
#  25
# در بهترین حالت، بیشترین اجاره خانه ای که توان پرداختش را داری چقدره؟
#  7000000
# << Mortgage = 400,000,000 >>
# << Rent = 0 >>
#
# profit:98,983,092
# cost:133,333,333
# Total:-34,350,241
#
# ---------------------------------------------------
#
#
#
#
# << Mortgage = 350,000,000 >>
# << Rent = 1,500,000 >>
#
# profit:90,272,430
# cost:134,666,667
# Total:-44,394,237
#
# ---------------------------------------------------
#
#
#
#
# << Mortgage = 300,000,000 >>
# << Rent = 3,000,000 >>
#
# profit:81,561,768
# cost:136,000,000
# Total:-54,438,232
#
# ---------------------------------------------------
#
#
#
#
# << Mortgage = 250,000,000 >>
# << Rent = 4,500,000 >>
#
# profit:72,851,104
# cost:137,333,333
# Total:-64,482,229
#
# ---------------------------------------------------
#
#
#
#
# << Mortgage = 200,000,000 >>
# << Rent = 6,000,000 >>
#
# profit:64,140,443
# cost:138,666,667
# Total:-74,526,224
#
# ---------------------------------------------------
